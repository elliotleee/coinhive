# %%
file_temp = locals()
file_list = []
file_name = []
func_name = []
Targets = []
operater = []
mem_operater = []

# %%
for i in range(9,38):
    file_name.append("wasm-000454f2-" + str(i))
    file = open("./wasm_code/"+file_name[i-9])
    func_name.append(file.readline().strip().split(' ')[1].strip('$'))
print(func_name)
# Out:
# ['f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', '_malloc', 'f17', '_aesb_single_round', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', '_cryptonight_destroy', '_cryptonight_create', 'f30', 'f31', 'f32', 'f33', 'f34', '_cryptonight_hash_variant_1', '_cryptonight_hash_variant_0', 'stackAlloc']

# %%
# for i in range(9,38):
#     file_name.append("wasm-000454f2-" + str(i))
#     file = open("./wasm_code/"+file_name[i-9])
#     file_temp['f%s'%i] = file
#     file_list.append(file)
    #get function name XD
    #print(file.readline().strip())
    #for line in file.readlines(): 
# read input data, get function code using f+integer

#dirtectly put into matrix
for i in range(9,38):
    temp = []
    file_name.append("wasm-000454f2-" + str(i))
    file = open("./wasm_code/"+file_name[i-9])
    for line in file:
        line = line.strip('\n')  
        line = line.strip(' ')
        temp.append(line)
    Targets.append(temp)
    file_list.append(file)

# %%
for file in Targets:
    file.pop(0)
    file.pop(0)
    print(file)
# Out:
# ['get_local 0', 'get_local 0', 'i32.load offset=0 align=4', 'tee_local 3', 'i32.const 255', 'i32.and', 'i32.const 2', 'i32.shl', 'i32.const 1024', 'i32.add', 'i32.load offset=0 align=4', 'get_local 1', 'i32.load offset=0 align=4', 'i32.xor', 'get_local 0', 'i32.const 4', 'i32.add', 'tee_local 9', 'i32.load offset=0 align=4', 'tee_local 4', 'i32.const 8', 'i32.shr_u', 'i32.const 255', 'i32.and', 'i32.const 2', 'i32.shl', 'i32.const 2048', 'i32.add', 'i32.load offset=0 align=4', 'i32.xor', 'get_local 0', 'i32.const 8', 'i32.add', 'tee_local 10', 'i32.load offset=0 align=4', 'tee_local 5', 'i32.const 16', 'i32.shr_u', 'i32.const 255', 'i32.and', 'i32.const 2', 'i32.shl', 'i32.const 3072', 'i32.add', 'i32.load offset=0 align=4', 'i32.xor', 'get_local 0', 'i32.const 12', 'i32.add', 'tee_local 11', 'i32.load offset=0 align=4', 'tee_local 2', 'i32.const 24', 'i32.shr_u', 'i32.const 2', 'i32.shl', 'i32.const 4096', 'i32.add', 'i32.load offset=0 align=4', 'i32.xor', 'tee_local 6', 'i32.const 
# ...

# %%
for file in Targets:
    for line in file:
        temp = line.split(' ')
        if temp[0] not in operater:
            operater.append(temp[0])

# %%
for file in Targets:
    for line in file:
        print(line)
# Out:
# get_local 0
# get_local 0
# i32.load offset=0 align=4
# tee_local 3
# i32.const 255
# i32.and
# i32.const 2
# i32.shl
# i32.const 1024
# i32.add
# i32.load offset=0 align=4
# get_local 1
# i32.load offset=0 align=4
# i32.xor
# get_local 0
# i32.const 4
# i32.add
# tee_local 9
# i32.load offset=0 align=4
# tee_local 4
# i32.const 8
# i32.shr_u
# i32.const 255
# i32.and
# i32.const 2
# i32.shl
# i32.const 2048
# i32.add
# i32.load offset=0 align=4
# i32.xor
# get_local 0
# i32.const 8
# i32.add
# tee_local 10
# i32.load offset=0 align=4
# tee_local 5
# i32.const 16
# i32.shr_u
# i32.const 255
# i32.and
# i32.const 2
# i32.shl
# i32.const 3072
# i32.add
# i32.load offset=0 align=4
# i32.xor
# get_local 0
# i32.const 12
# i32.add
# tee_local 11
# i32.load offset=0 align=4
# tee_local 2
# i32.const 24
# i32.shr_u
# i32.const 2
# i32.shl
# i32.const 4096
# i32.add
# i32.load offset=0 align=4
# i32.xor
# tee_local 6
# i32.const 255
# i32.and
# i32.const 2
# i32.shl
# i32.const 1024
# ...

# %%
print(operater)
# Out:
# ['get_local', 'i32.load', 'tee_local', 'i32.const', 'i32.and', 'i32.shl', 'i32.add', 'i32.xor', 'i32.shr_u', 'i32.store', 'end', 'set_local', 'i32.load8_u', 'i32.or', 'i32.ge_s', 'if', 'call', 'return', 'i32.eq', 'loop', 'i32.eqz', 'i32.load8_s', 'i32.store8', 'i32.sub', 'br', 'i32.le_s', 'i32.lt_s', 'else', 'block', 'i32.lt_u', 'i32.ne', 'br_if', 'drop', 'unreachable', 'i32.ge_u', 'i32.gt_u', 'get_global', 'i32.gt_s', 'set_global', 'i32.le_u', 'i64.load', 'i64.store', 'i32.shr_s', 'i64.const', 'i64.shr_u', 'i64.and', 'i64.extend_u/i32', 'i64.ge_u', 'i64.extend_s/i32', 'i64.sub', 'i64.gt_u', 'i64.add', 'i64.eq', 'i32.wrap/i64', 'i64.store32', 'i32.rem_u', 'i32.div_u', 'i64.xor', 'i64.shl', 'i64.or', 'i64.lt_u', 'i64.mul', 'i32.load16_u', 'i32.load16_s', 'i32.store16', 'br_table', 'i64.ne', 'i64.store8', 'call_indirect']

# %%
Operater = ['i32.const','i32.shl','i32.add','i32.xor','i32.shr_u', 'i32.or', 'i32.ge_s', 'i32.eq','loop','i32.eqz','i32.load8_s','i32.sub', 'i32.le_s', 'i32.lt_s', 'i32.lt_u', 'i32.ne', 'br_if', 'i32.ge_u', 'i32.gt_u', 'i32.gt_s', 'i32.le_u', 'i32.shr_s', 'i64.shr_u', 'i64.and', 'i64.extend_u/i32', 'i64.ge_u', 'i64.extend_s/i32', 'i64.sub', 'i64.gt_u', 'i64.add', 'i64.eq', 'i32.wrap/i64', 'i64.store32', 'i32.rem_u', 'i32.div_u', 'i64.xor', 'i64.shl', 'i64.or', 'i64.lt_u', 'i64.mul', 'br_table']
Mem_operater = ['get_local','i32.load','tee_local', 'i32.store','set_local', 'i32.load8_u','i32.store8', 'i64.load', 'i64.store','i32.load16_u', 'i32.load16_s','i32.store16', 'i64.ne', 'i64.store8']
ShiftRow = ['i32.shl','i32.shr_u', 'i32.shr_s','i64.shr_u', 'i64.shl']
Const = ['i32.const','i64.const']
And = ['i32.and','i64.and']
Xor = ['i32.xor','i64.xor']

# %%
#fingerprint
#asb_fingerprint = [['Const','255'],['And'],['ShiftRow','2'],['Xor'],['Mem_operater']]
asb_fingerprint = [['Const','255'],['And'],['ShiftRow','2'],['Xor'],['Mem_operater']]

# %%
def getconstTarget(line):
    return line.split(' ')[1]

# %%
#split into code block
def blocksplit(Target):
    pass

# %%
#simple version of code split
Result = []
def simplesplit(Target):
    for line in Target:
        templine = line.split(' ')
        if templine[0] in Const:
            templine[0] ='Const'
            templine.append(line)
            Result.append(templine)
        elif templine[0] in Xor:
            templine[0] ='Xor'
            templine.append(line)
            Result.append(templine)
        elif templine[0] in ShiftRow:
            templine[0] ='ShiftRow'
            templine.append(line)
            Result.append(templine)
        elif templine[0] in And:
            templine[0] ='And'
            templine.append(line)
            Result.append(templine)
        elif templine[0] in Mem_operater:
            templine[0] ='Mem_operater'
            templine.append(line)
            Result.append(templine)
    return Result

# %%
# future 
def hardcheck(Target,fingerprint):
    for feather in fingerprint:
        if feather[0] == 'Const':
            pass
        elif feather[0] == 'And':
            pass
        elif feather[0] == 'ShiftRow':
            pass
        elif feather[0] == 'Xor':
            pass
        elif feather[0] == 'Mem_operater':
            pass

# %%
# def softcheck(Target,fingerprint):
#     for feather in fingerprint:
#         if feather[0] == 'Const':
#             for line in Target:
#                 if line[0] == 
#         elif feather[0] == 'And':
#             pass
#         elif feather[0] == 'ShiftRow':
#             pass
#         elif feather[0] == 'Xor':
#             pass
#         elif feather[0] == 'Mem_operater':
#             pass
check_result = []
def softcheck(Target,fingerprint):
    check_result.clear()
    for feather in fingerprint:
        for line in Target:
            if feather[0] == line[0]:
                if feather[0] == 'Const' or feather[0] == 'ShiftRow':
                    if feather[1] == line[1]:
                        check_result.append(line[2])
                        continue
                check_result.append(line[1])
                continue
    print('similiar_percent: {:.2%}'.format(len(check_result)/len(fingerprint)))
    return check_result

# %%
for file in Targets:
    result = simplesplit(file)
    checkresult = softcheck(result,asb_fingerprint)
# Out:
# similiar_percent: 63600.00%
# similiar_percent: 100220.00%
# similiar_percent: 103380.00%
# similiar_percent: 116380.00%
# similiar_percent: 154340.00%
# similiar_percent: 156460.00%
# similiar_percent: 156960.00%
# similiar_percent: 208820.00%
# similiar_percent: 210800.00%
# similiar_percent: 213840.00%
# similiar_percent: 213840.00%
# similiar_percent: 221640.00%
# similiar_percent: 235500.00%
# similiar_percent: 291920.00%
# similiar_percent: 359440.00%
# similiar_percent: 370840.00%
# similiar_percent: 405700.00%
# similiar_percent: 433500.00%
# similiar_percent: 455240.00%
# similiar_percent: 456040.00%
# similiar_percent: 462180.00%
# similiar_percent: 473960.00%
# similiar_percent: 474580.00%
# similiar_percent: 487180.00%
# similiar_percent: 496460.00%
# similiar_percent: 503320.00%
# similiar_percent: 522940.00%
# similiar_percent: 541220.00%
# similiar_percent: 541340.00%

# %%
print(checkresult)
# Out:
# ['i32.const 255', '2', '1024', '4', '8', 'i32.const 255', '2', '2048', '8', '16', 'i32.const 255', '2', '3072', '12', '24', '2', '4096', 'i32.const 255', '2', '1024', 'i32.const 255', '2', '1024', '8', 'i32.const 255', '2', '2048', '16', 'i32.const 255', '2', '3072', '24', '2', '4096', '8', 'i32.const 255', '2', '2048', 'i32.const 255', '2', '1024', '8', 'i32.const 255', '2', '2048', '16', 'i32.const 255', '2', '3072', '24', '2', '4096', '16', 'i32.const 255', '2', '3072', 'i32.const 255', '2', '1024', '8', 'i32.const 255', '2', '2048', '16', 'i32.const 255', '2', '3072', '24', '2', '4096', '24', '2', '4096', 'i32.const 255', '2', '1024', '8', 'i32.const 255', '2', '2048', '16', 'i32.const 255', '2', '3072', '24', '2', '4096', 'i32.const 255', '2', '1024', '8', 'i32.const 255', '2', '2048', '16', 'i32.const 255', '2', '3072', '24', '2', '4096', 'i32.const 255', '2', '1024', '8', 'i32.const 255', '2', '2048', '16', 'i32.const 255', '2', '3072', '24', '2', '4096', 'i32.const 255', '2',
# ...
