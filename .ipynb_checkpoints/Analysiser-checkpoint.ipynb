# %% [markdown]
# ## C version coinhive code detect heading

# %%
#file = open("./diviedfunc/f9") 
file = open("./worker.c")
lines= []
operater = ['=', '&=', '<<=', '+=', '^=', '>>=', '|=']
mem_operater = ['i32_load','i64_load','i32_store','i32_store']
func_name = []
mem_line = []
cal_line = []

# %%
linetable =[]

# %%
# for line in file:
#     pass # do something
# file.close()
for line in file.readlines(): 
    #deal with line, delete no need char
    line = line.strip('\n')  
    line = line.strip(' ')
    line = line.strip(';')
    line = line.strip('u')
    
    # split line
   
    lines.append(line)
    print(line)
    # use to get operater
    #if temp[1] not in operater:
    #    operater.append(temp[1])
# Out:
# #include <assert.h>
# #include <math.h>
# #include <stdlib.h>
# #include <string.h>
#
# #include "/home/elliot/Desktop/UB/wang_xian_nv_de_ren_wu/code/worker.h"
# #define UNLIKELY(x) __builtin_expect(!!(x), 0)
# #define LIKELY(x) __builtin_expect(!!(x), 1)
#
# #define TRAP(x) (wasm_rt_trap(WASM_RT_TRAP_##x), 0)
#
# #define FUNC_PROLOGUE                                            \
# if (++wasm_rt_call_stack_depth > WASM_RT_MAX_CALL_STACK_DEPTH) \
# TRAP(EXHAUSTION)
#
# #define FUNC_EPILOGUE --wasm_rt_call_stack_depth
#
# #define UNREACHABLE TRAP(UNREACHABLE)
#
# #define CALL_INDIRECT(table, t, ft, x, ...)          \
# (LIKELY((x) < table.size && table.data[x].func &&  \
# table.data[x].func_type == func_types[ft]) \
# ? ((t)table.data[x].func)(__VA_ARGS__)        \
# : TRAP(CALL_INDIRECT))
#
# #define MEMCHECK(mem, a, t)  \
# if (UNLIKELY((a) + sizeof(t) > mem->size)) TRAP(OOB)
#
# #define DEFINE_LOAD(name, t1, t2, t3)              \
# static inline t3 name(wasm_rt_memory_t* mem, u64 addr) {   \
# MEMCHECK(mem, addr, t1);                       \
# t1 result;                                     \
# memcpy(&result, &mem->data[addr], sizeof(t1)); \
# return (t3)(t2)result;                         \
# }
#
# #define DEFINE_STORE(name, t1, t2)                           \
# static inline void name(wasm_rt_memory_t* mem, u64 addr, t2 value) { \
# MEMCHECK(mem, addr, t1);                                 \
# t1 wrapped = (t1)value;                                  \
# memcpy(&mem->data[addr], &wrapped, sizeof(t1));          \
# }
#
# DEFINE_LOAD(i32_load, u32, u32, u32)
# DEFINE_LOAD(i64_load, u64, u64, u64)
# DEFINE_LOAD(f32_load, f32, f32, f32)
# DEFINE_LOAD(f64_load, f64, f64, f64)
# DEFINE_LOAD(i32_load8_s, s8, s32, u32)
# DEFINE_LOAD(i64_load8_s, s8, s64, u64)
# DEFINE_LOAD(i32_load8_u, u8, u32, u32)
# DEFINE_LOAD(i64_load8_u, u8, u64, u64)
# DEFINE_LOAD(i32_load16_s, s16, s32, u32)
# DEFINE_LOAD(i64_load16_s, s16, s64, u64)
# DEFINE_LOAD(i32_load16_u, u16, u32, u32)
# DEFINE_LOAD(i64_load16_u, u16, u64, u64)
# DEFINE_LOAD(i64_load32_s, s32, s64, u64)
# DEFINE_LOAD(i64_load32_u, u32, u64, u64)
# DEFINE_STORE(i32_store, u32, u32)
# DEFINE_STORE(i64_store, u64, u64)
# DEFINE_STORE(f32_store, f32, f32)
# DEFINE_STORE(f64_store, f64, f64)
# DEFINE_STORE(i32_store8, u8, u32)
# DEFINE_STORE(i32_store16, u16, u32)
# DEFINE_STORE(i64_store8, u8, u64)
# DEFINE_STORE(i64_store16, u16, u64)
# DEFINE_STORE(i64_store32, u32, u64)
#
# #define I32_CLZ(x) ((x) ? __builtin_clz(x) : 32)
# #define I64_CLZ(x) ((x) ? __builtin_clzll(x) : 64)
# #define I32_CTZ(x) ((x) ? __builtin_ctz(x) : 32)
# #define I64_CTZ(x) ((x) ? __builtin_ctzll(x) : 64)
# #define I32_POPCNT(x) (__builtin_popcount(x))
# #define I64_POPCNT(x) (__builtin_popcountll(x))
#
# #define DIV_S(ut, min, x, y)                                 \
# ((UNLIKELY((y) == 0)) ?                TRAP(DIV_BY_ZERO)  \
# : (UNLIKELY((x) == min && (y) == -1)) ? TRAP(INT_OVERFLOW) \
# : (ut)((x) / (y)))
#
# #define REM_S(ut, min, x, y)                                \
# ((UNLIKELY((y) == 0)) ?                TRAP(DIV_BY_ZERO) \
# : (UNLIKELY((x) == min && (y) == -1)) ? 0                 \
# : (ut)((x) % (y)))
#
# #define I32_DIV_S(x, y) DIV_S(u32, INT32_MIN, (s32)x, (s32)y)
# #define I64_DIV_S(x, y) DIV_S(u64, INT64_MIN, (s64)x, (s64)y)
# #define I32_REM_S(x, y) REM_S(u32, INT32_MIN, (s32)x, (s32)y)
# #define I64_REM_S(x, y) REM_S(u64, INT64_MIN, (s64)x, (s64)y)
#
# #define DIVREM_U(op, x, y) \
# ((UNLIKELY((y) == 0)) ? TRAP(DIV_BY_ZERO) : ((x) op (y)))
#
# #define DIV_U(x, y) DIVREM_U(/, x, y)
# #define REM_U(x, y) DIVREM_U(%, x, y)
#
# #define ROTL(x, y, mask) \
# (((x) << ((y) & (mask))) | ((x) >> (((mask) - (y) + 1) & (mask))))
# #define ROTR(x, y, mask) \
# (((x) >> ((y) & (mask))) | ((x) << (((mask) - (y) + 1) & (mask))))
#
# #define I32_ROTL(x, y) ROTL(x, y, 31)
# #define I64_ROTL(x, y) ROTL(x, y, 63)
# #define I32_ROTR(x, y) ROTR(x, y, 31)
# #define I64_ROTR(x, y) ROTR(x, y, 63)
#
# #define FMIN(x, y)                                          \
# ((UNLIKELY((x) != (x))) ? NAN                            \
# : (UNLIKELY((y) != (y))) ? NAN                            \
# : (UNLIKELY((x) == 0 && (y) == 0)) ? (signbit(x) ? x : y) \
# : (x < y) ? x : y)
#
# #define FMAX(x, y)                                          \
# ((UNLIKELY((x) != (x))) ? NAN                            \
# : (UNLIKELY((y) != (y))) ? NAN                            \
# : (UNLIKELY((x) == 0 && (y) == 0)) ? (signbit(x) ? y : x) \
# : (x > y) ? x : y)
#
# #define TRUNC_S(ut, st, ft, min, max, maxop, x)                             \
# ((UNLIKELY((x) != (x))) ? TRAP(INVALID_CONVERSION)                       \
# : (UNLIKELY((x) < (ft)(min) || (x) maxop (ft)(max))) ? TRAP(INT_OVERFLOW) \
# : (ut)(st)(x))
#
# #define I32_TRUNC_S_F32(x) TRUNC_S(u32, s32, f32, INT32_MIN, INT32_MAX, >=, x)
# #define I64_TRUNC_S_F32(x) TRUNC_S(u64, s64, f32, INT64_MIN, INT64_MAX, >=, x)
# #define I32_TRUNC_S_F64(x) TRUNC_S(u32, s32, f64, INT32_MIN, INT32_MAX, >,  x)
# #define I64_TRUNC_S_F64(x) TRUNC_S(u64, s64, f64, INT64_MIN, INT64_MAX, >=, x)
#
# #define TRUNC_U(ut, ft, max, maxop, x)                                    \
# ((UNLIKELY((x) != (x))) ? TRAP(INVALID_CONVERSION)                     \
# : (UNLIKELY((x) <= (ft)-1 || (x) maxop (ft)(max))) ? TRAP(INT_OVERFLOW) \
# : (ut)(x))
#
# #define I32_TRUNC_U_F32(x) TRUNC_U(u32, f32, UINT32_MAX, >=, x)
# #define I64_TRUNC_U_F32(x) TRUNC_U(u64, f32, UINT64_MAX, >=, x)
# #define I32_TRUNC_U_F64(x) TRUNC_U(u32, f64, UINT32_MAX, >,  x)
# #define I64_TRUNC_U_F64(x) TRUNC_U(u64, f64, UINT64_MAX, >=, x)
#
# #define DEFINE_REINTERPRET(name, t1, t2)  \
# static inline t2 name(t1 x) {           \
# t2 result;                            \
# memcpy(&result, &x, sizeof(result));  \
# return result;                        \
# }
#
# DEFINE_REINTERPRET(f32_reinterpret_i32, u32, f32)
# DEFINE_REINTERPRET(i32_reinterpret_f32, f32, u32)
# DEFINE_REINTERPRET(f64_reinterpret_i64, u64, f64)
# DEFINE_REINTERPRET(i64_reinterpret_f64, f64, u64)
#
#
# static u32 func_types[9]
#
# static void init_func_types(void) {
# func_types[0] = wasm_rt_register_func_type(3, 0, WASM_RT_I32, WASM_RT_I32, WASM_RT_I32)
# func_types[1] = wasm_rt_register_func_type(1, 0, WASM_RT_I32)
# func_types[2] = wasm_rt_register_func_type(0, 1, WASM_RT_I32)
# func_types[3] = wasm_rt_register_func_type(2, 1, WASM_RT_I32, WASM_RT_I32, WASM_RT_I32)
# func_types[4] = wasm_rt_register_func_type(3, 1, WASM_RT_I32, WASM_RT_I32, WASM_RT_I32, WASM_RT_I32)
# func_types[5] = wasm_rt_register_func_type(1, 1, WASM_RT_I32, WASM_RT_I32)
# func_types[6] = wasm_rt_register_func_type(2, 0, WASM_RT_I32, WASM_RT_I32)
# func_types[7] = wasm_rt_register_func_type(4, 0, WASM_RT_I32, WASM_RT_I32, WASM_RT_I32, WASM_RT_I32)
# func_types[8] = wasm_rt_register_func_type(3, 0, WASM_RT_I32, WASM_RT_I32, WASM_RT_I64)
# }
#
# static void f9(u32, u32)
# static void f10(u32, u32, u32)
# static u32 f11(u32, u32, u32)
# static void f12(u32)
# static void f13(u32, u32, u32)
# static u32 f14(u32, u32, u32)
# static u32 f15(u32)
# static u32 _malloc(u32)
# static void f17(u32, u32, u64)
# static void f18(u32, u32, u32)
# static void f19(u32, u32)
# static void f20(u32)
# static void f21(u32)
# static void f22(u32, u32, u32)
# static void f23(u32, u32, u32, u32)
# static void f24(u32, u32, u32)
# static void f25(u32, u32, u32, u32)
# static void f26(u32, u32, u32, u32)
# static void f27(u32, u32)
# static void _cryptonight_destroy(u32)
# static u32 _cryptonight_create(void)
# static void f30(u32, u32, u32)
# static u32 f31(u32, u32, u32)
# static void f32_0(u32, u32, u32)
# static void f33(u32, u32, u32)
# static void f34(u32, u32, u32)
# static void _cryptonight_hash_variant_1(u32, u32, u32, u32)
# static void _cryptonight_hash_variant_0(u32, u32, u32, u32)
# static u32 stackAlloc(u32)
#
# static u32 g3
# static u32 g4
#
# static void init_globals(void) {
# g3 = (*Z_envZ_DYNAMICTOP_PTRZ_i)
# g4 = (*Z_envZ_STACKTOPZ_i)
# }
#
# static void f9(u32 p0, u32 p1) {
# 32 l0 = 0, l1 = 0, l2 = 0, l3 = 0, l4 = 0, l5 = 0, l6 = 0, l7 = 0,
# l8 = 0, l9 = 0
# FUNC_PROLOGUE
# 32 i0, i1, i2, i3, i4
# i0 = p0
# i1 = p0
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l1 = i1
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = p0
# i3 = 4
# i2 += i3
# l7 = i2
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# l2 = i2
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = p0
# i3 = 8
# i2 += i3
# l8 = i2
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# l3 = i2
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = p0
# i3 = 12
# i2 += i3
# l9 = i2
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# l0 = i2
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l4 = i1
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 16))
# i1 ^= i2
# i2 = l2
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 4))
# i2 ^= i3
# i3 = l3
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l0
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l1
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l5 = i2
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l3
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 8))
# i2 ^= i3
# i3 = l0
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l1
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l2
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l6 = i2
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 12))
# i2 ^= i3
# i3 = l1
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l2
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l3
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l0 = i2
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l1 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l7
# i1 = l5
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 20))
# i1 ^= i2
# i2 = l6
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l4
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l2 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l8
# i1 = l6
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 24))
# i1 ^= i2
# i2 = l0
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l4
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l5
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l3 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l9
# i1 = l0
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 28))
# i1 ^= i2
# i2 = l4
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l5
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l6
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l0 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p0
# i1 = l1
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 32))
# i1 ^= i2
# i2 = l2
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l3
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l4 = i1
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 48))
# i1 ^= i2
# i2 = l2
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 36))
# i2 ^= i3
# i3 = l3
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l0
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l1
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l5 = i2
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l3
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 40))
# i2 ^= i3
# i3 = l0
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l1
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l2
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l6 = i2
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 44))
# i2 ^= i3
# i3 = l1
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l2
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l3
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l0 = i2
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l1 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l7
# i1 = l5
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 52))
# i1 ^= i2
# i2 = l6
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l4
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l2 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l8
# i1 = l6
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 56))
# i1 ^= i2
# i2 = l0
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l4
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l5
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l3 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l9
# i1 = l0
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 60))
# i1 ^= i2
# i2 = l4
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l5
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l6
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l0 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p0
# i1 = l1
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 64))
# i1 ^= i2
# i2 = l2
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l3
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l4 = i1
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 80))
# i1 ^= i2
# i2 = l2
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 68))
# i2 ^= i3
# i3 = l3
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l0
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l1
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l5 = i2
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l3
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 72))
# i2 ^= i3
# i3 = l0
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l1
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l2
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l6 = i2
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 76))
# i2 ^= i3
# i3 = l1
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l2
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l3
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l0 = i2
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l1 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l7
# i1 = l5
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 84))
# i1 ^= i2
# i2 = l6
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l4
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l2 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l8
# i1 = l6
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 88))
# i1 ^= i2
# i2 = l0
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l4
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l5
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l3 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l9
# i1 = l0
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 92))
# i1 ^= i2
# i2 = l4
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l5
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l6
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l0 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p0
# i1 = l1
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 96))
# i1 ^= i2
# i2 = l2
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l3
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l4 = i1
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 112))
# i1 ^= i2
# i2 = l2
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 100))
# i2 ^= i3
# i3 = l3
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l0
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l1
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l5 = i2
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l3
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 104))
# i2 ^= i3
# i3 = l0
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l1
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l2
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l6 = i2
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 108))
# i2 ^= i3
# i3 = l1
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l2
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l3
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l0 = i2
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l1 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l7
# i1 = l5
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 116))
# i1 ^= i2
# i2 = l6
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l4
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l2 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l8
# i1 = l6
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 120))
# i1 ^= i2
# i2 = l0
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l4
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l5
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l3 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l9
# i1 = l0
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 124))
# i1 ^= i2
# i2 = l4
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l5
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l6
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# l0 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p0
# i1 = l1
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 128))
# i1 ^= i2
# i2 = l2
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l3
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# p0 = i1
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 144))
# i1 ^= i2
# i2 = l2
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 132))
# i2 ^= i3
# i3 = l3
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l0
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l1
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l4 = i2
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l3
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 136))
# i2 ^= i3
# i3 = l0
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l1
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l2
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l5 = i2
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l0
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 1024
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i3 = p1
# i3 = i32_load(Z_envZ_memory, (u64)(i3 + 140))
# i2 ^= i3
# i3 = l1
# i4 = 8
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 2048
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l2
# i4 = 16
# i3 >>= (i4 & 31)
# i4 = 255
# i3 &= i4
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 3072
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# i3 = l3
# i4 = 24
# i3 >>= (i4 & 31)
# i4 = 2
# i3 <<= (i4 & 31)
# i4 = 4096
# i3 += i4
# i3 = i32_load(Z_envZ_memory, (u64)(i3))
# i2 ^= i3
# l1 = i2
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l7
# i1 = l4
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 148))
# i1 ^= i2
# i2 = l5
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l1
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = p0
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l8
# i1 = l5
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 152))
# i1 ^= i2
# i2 = l1
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = p0
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l4
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l9
# i1 = l1
# i2 = 255
# i1 &= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 1024
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p1
# i2 = i32_load(Z_envZ_memory, (u64)(i2 + 156))
# i1 ^= i2
# i2 = p0
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 2048
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l4
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = 255
# i2 &= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 3072
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l5
# i3 = 24
# i2 >>= (i3 & 31)
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 4096
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# FUNC_EPILOGUE
# }
#
# static void f10(u32 p0, u32 p1, u32 p2) {
# 32 l0 = 0, l1 = 0, l2 = 0, l3 = 0, l4 = 0, l5 = 0, l6 = 0, l7 = 0,
# l8 = 0, l9 = 0, l10 = 0, l11 = 0, l12 = 0, l13 = 0, l14 = 0, l15 = 0,
# l16 = 0, l17 = 0, l18 = 0, l19 = 0, l20 = 0
# FUNC_PROLOGUE
# 32 i0, i1, i2, i3, i4
# i0 = p0
# i1 = p0
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i2 = p2
# i1 ^= i2
# l1 = i1
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p2
# i1 = 16
# i0 ^= i1
# i1 = p0
# i2 = 8
# i1 += i2
# l8 = i1
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i0 ^= i1
# l4 = i0
# i0 = l8
# i1 = l4
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p2
# i1 = 32
# i0 ^= i1
# i1 = p0
# i2 = 16
# i1 += i2
# l9 = i1
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i0 ^= i1
# l5 = i0
# i0 = l9
# i1 = l5
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p2
# i1 = 48
# i0 ^= i1
# i1 = p0
# i2 = 24
# i1 += i2
# l11 = i1
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i0 ^= i1
# l0 = i0
# i0 = l11
# i1 = l0
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p0
# i1 = 32
# i0 += i1
# l12 = i0
# i1 = p2
# i2 = 64
# i1 ^= i2
# i2 = l12
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p0
# i1 = 40
# i0 += i1
# l14 = i0
# i1 = p2
# i2 = 80
# i1 ^= i2
# i2 = l14
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p0
# i1 = 48
# i0 += i1
# l16 = i0
# i1 = p2
# i2 = 96
# i1 ^= i2
# i2 = l16
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p0
# i1 = 56
# i0 += i1
# l18 = i0
# i1 = p2
# i2 = 112
# i1 ^= i2
# i2 = l18
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = l4
# i1 = 7
# i0 >>= (i1 & 31)
# i1 = 510
# i0 &= i1
# l6 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# p2 = i0
# i0 = l5
# i1 = 15
# i0 >>= (i1 & 31)
# i1 = 510
# i0 &= i1
# l7 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l4 = i0
# i0 = l0
# i1 = 24
# i0 >>= (i1 & 31)
# i1 = 1
# i0 <<= (i1 & 31)
# l10 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l5 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 45))
# i1 = 1
# i0 <<= (i1 & 31)
# l13 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l0 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 54))
# i1 = 1
# i0 <<= (i1 & 31)
# l15 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l3 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 63))
# i1 = 1
# i0 <<= (i1 & 31)
# l17 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l2 = i0
# i0 = l6
# i1 = 1
# i0 |= i1
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l6 = i0
# i1 = 8
# i0 <<= (i1 & 31)
# i1 = p2
# i2 = 24
# i1 >>= (i2 & 31)
# i0 |= i1
# i1 = l1
# i2 = 1
# i1 <<= (i2 & 31)
# i2 = 510
# i1 &= i2
# l1 = i1
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i0 ^= i1
# i1 = l7
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l7 = i1
# i2 = 16
# i1 <<= (i2 & 31)
# i2 = l4
# i3 = 16
# i2 >>= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l10
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l10 = i1
# i2 = 24
# i1 <<= (i2 & 31)
# i2 = l5
# i3 = 8
# i2 >>= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = p0
# i1 = i32_load8_u(Z_envZ_memory, (u64)(i1 + 36))
# i2 = 1
# i1 <<= (i2 & 31)
# l19 = i1
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i0 ^= i1
# i1 = l13
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l13 = i1
# i2 = 24
# i1 >>= (i2 & 31)
# i2 = l0
# i3 = 8
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l15
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l15 = i1
# i2 = 16
# i1 >>= (i2 & 31)
# i2 = l3
# i3 = 16
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l17
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l17 = i1
# i2 = 8
# i1 >>= (i2 & 31)
# i2 = l2
# i3 = 24
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# l20 = i0
# i0 = p1
# i1 = l6
# i2 = 24
# i1 >>= (i2 & 31)
# i2 = p2
# i3 = 8
# i2 <<= (i3 & 31)
# i1 |= i2
# i2 = l1
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 5456
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l7
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = l4
# i4 = 16
# i3 <<= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l10
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = l5
# i4 = 24
# i3 <<= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l19
# i3 = 1
# i2 |= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 5456
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l13
# i3 = 8
# i2 <<= (i3 & 31)
# i3 = l0
# i4 = 24
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l15
# i3 = 16
# i2 <<= (i3 & 31)
# i3 = l3
# i4 = 16
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l17
# i3 = 24
# i2 <<= (i3 & 31)
# i3 = l2
# i4 = 8
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0), i1)
# i0 = p1
# i1 = l20
# i32_store(Z_envZ_memory, (u64)(i0 + 4), i1)
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 17))
# i1 = 1
# i0 <<= (i1 & 31)
# l1 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# p2 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 26))
# i1 = 1
# i0 <<= (i1 & 31)
# l6 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l4 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 35))
# i1 = 1
# i0 <<= (i1 & 31)
# l7 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l5 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 53))
# i1 = 1
# i0 <<= (i1 & 31)
# l10 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l0 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 62))
# i1 = 1
# i0 <<= (i1 & 31)
# l13 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l3 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 7))
# i1 = 1
# i0 <<= (i1 & 31)
# l15 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l2 = i0
# i0 = l1
# i1 = 1
# i0 |= i1
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l1 = i0
# i1 = 8
# i0 <<= (i1 & 31)
# i1 = p2
# i2 = 24
# i1 >>= (i2 & 31)
# i0 |= i1
# i1 = l8
# i1 = i32_load8_u(Z_envZ_memory, (u64)(i1))
# i2 = 1
# i1 <<= (i2 & 31)
# l8 = i1
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i0 ^= i1
# i1 = l6
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l6 = i1
# i2 = 16
# i1 <<= (i2 & 31)
# i2 = l4
# i3 = 16
# i2 >>= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l7
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l7 = i1
# i2 = 24
# i1 <<= (i2 & 31)
# i2 = l5
# i3 = 8
# i2 >>= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = p0
# i1 = i32_load8_u(Z_envZ_memory, (u64)(i1 + 44))
# i2 = 1
# i1 <<= (i2 & 31)
# l17 = i1
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i0 ^= i1
# i1 = l10
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l10 = i1
# i2 = 24
# i1 >>= (i2 & 31)
# i2 = l0
# i3 = 8
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l13
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l13 = i1
# i2 = 16
# i1 >>= (i2 & 31)
# i2 = l3
# i3 = 16
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l15
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l15 = i1
# i2 = 8
# i1 >>= (i2 & 31)
# i2 = l2
# i3 = 24
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# l19 = i0
# i0 = p1
# i1 = l1
# i2 = 24
# i1 >>= (i2 & 31)
# i2 = p2
# i3 = 8
# i2 <<= (i3 & 31)
# i1 |= i2
# i2 = l8
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 5456
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l6
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = l4
# i4 = 16
# i3 <<= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l7
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = l5
# i4 = 24
# i3 <<= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l17
# i3 = 1
# i2 |= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 5456
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l10
# i3 = 8
# i2 <<= (i3 & 31)
# i3 = l0
# i4 = 24
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l13
# i3 = 16
# i2 <<= (i3 & 31)
# i3 = l3
# i4 = 16
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l15
# i3 = 24
# i2 <<= (i3 & 31)
# i3 = l2
# i4 = 8
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0 + 8), i1)
# i0 = p1
# i1 = l19
# i32_store(Z_envZ_memory, (u64)(i0 + 12), i1)
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 25))
# i1 = 1
# i0 <<= (i1 & 31)
# l2 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# p2 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 34))
# i1 = 1
# i0 <<= (i1 & 31)
# l1 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l8 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 43))
# i1 = 1
# i0 <<= (i1 & 31)
# l6 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l4 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 61))
# i1 = 1
# i0 <<= (i1 & 31)
# l7 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l5 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 6))
# i1 = 1
# i0 <<= (i1 & 31)
# l10 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l0 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 15))
# i1 = 1
# i0 <<= (i1 & 31)
# l13 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l3 = i0
# i0 = l2
# i1 = 1
# i0 |= i1
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l2 = i0
# i1 = 8
# i0 <<= (i1 & 31)
# i1 = p2
# i2 = 24
# i1 >>= (i2 & 31)
# i0 |= i1
# i1 = l9
# i1 = i32_load8_u(Z_envZ_memory, (u64)(i1))
# i2 = 1
# i1 <<= (i2 & 31)
# l9 = i1
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i0 ^= i1
# i1 = l1
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l1 = i1
# i2 = 16
# i1 <<= (i2 & 31)
# i2 = l8
# i3 = 16
# i2 >>= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l6
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l6 = i1
# i2 = 24
# i1 <<= (i2 & 31)
# i2 = l4
# i3 = 8
# i2 >>= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = p0
# i1 = i32_load8_u(Z_envZ_memory, (u64)(i1 + 52))
# i2 = 1
# i1 <<= (i2 & 31)
# l15 = i1
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i0 ^= i1
# i1 = l7
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l7 = i1
# i2 = 24
# i1 >>= (i2 & 31)
# i2 = l5
# i3 = 8
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l10
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l10 = i1
# i2 = 16
# i1 >>= (i2 & 31)
# i2 = l0
# i3 = 16
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l13
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l13 = i1
# i2 = 8
# i1 >>= (i2 & 31)
# i2 = l3
# i3 = 24
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# l17 = i0
# i0 = p1
# i1 = l2
# i2 = 24
# i1 >>= (i2 & 31)
# i2 = p2
# i3 = 8
# i2 <<= (i3 & 31)
# i1 |= i2
# i2 = l9
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 5456
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l1
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = l8
# i4 = 16
# i3 <<= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l6
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = l4
# i4 = 24
# i3 <<= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l15
# i3 = 1
# i2 |= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 5456
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l7
# i3 = 8
# i2 <<= (i3 & 31)
# i3 = l5
# i4 = 24
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l10
# i3 = 16
# i2 <<= (i3 & 31)
# i3 = l0
# i4 = 16
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l13
# i3 = 24
# i2 <<= (i3 & 31)
# i3 = l3
# i4 = 8
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0 + 16), i1)
# i0 = p1
# i1 = l17
# i32_store(Z_envZ_memory, (u64)(i0 + 20), i1)
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 33))
# i1 = 1
# i0 <<= (i1 & 31)
# l3 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# p2 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 42))
# i1 = 1
# i0 <<= (i1 & 31)
# l2 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l8 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 51))
# i1 = 1
# i0 <<= (i1 & 31)
# l1 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l4 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 5))
# i1 = 1
# i0 <<= (i1 & 31)
# l6 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l9 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 14))
# i1 = 1
# i0 <<= (i1 & 31)
# l7 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l5 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 23))
# i1 = 1
# i0 <<= (i1 & 31)
# l10 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l0 = i0
# i0 = l3
# i1 = 1
# i0 |= i1
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l3 = i0
# i1 = 8
# i0 <<= (i1 & 31)
# i1 = p2
# i2 = 24
# i1 >>= (i2 & 31)
# i0 |= i1
# i1 = l11
# i1 = i32_load8_u(Z_envZ_memory, (u64)(i1))
# i2 = 1
# i1 <<= (i2 & 31)
# l11 = i1
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i0 ^= i1
# i1 = l2
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l2 = i1
# i2 = 16
# i1 <<= (i2 & 31)
# i2 = l8
# i3 = 16
# i2 >>= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l1
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l1 = i1
# i2 = 24
# i1 <<= (i2 & 31)
# i2 = l4
# i3 = 8
# i2 >>= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = p0
# i1 = i32_load8_u(Z_envZ_memory, (u64)(i1 + 60))
# i2 = 1
# i1 <<= (i2 & 31)
# l13 = i1
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# i0 ^= i1
# i1 = l6
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l6 = i1
# i2 = 24
# i1 >>= (i2 & 31)
# i2 = l9
# i3 = 8
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l7
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l7 = i1
# i2 = 16
# i1 >>= (i2 & 31)
# i2 = l5
# i3 = 16
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# i1 = l10
# i2 = 1
# i1 |= i2
# i2 = 2
# i1 <<= (i2 & 31)
# i2 = 5456
# i1 += i2
# i1 = i32_load(Z_envZ_memory, (u64)(i1))
# l10 = i1
# i2 = 8
# i1 >>= (i2 & 31)
# i2 = l0
# i3 = 24
# i2 <<= (i3 & 31)
# i1 |= i2
# i0 ^= i1
# l15 = i0
# i0 = p1
# i1 = l3
# i2 = 24
# i1 >>= (i2 & 31)
# i2 = p2
# i3 = 8
# i2 <<= (i3 & 31)
# i1 |= i2
# i2 = l11
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 5456
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l2
# i3 = 16
# i2 >>= (i3 & 31)
# i3 = l8
# i4 = 16
# i3 <<= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l1
# i3 = 8
# i2 >>= (i3 & 31)
# i3 = l4
# i4 = 24
# i3 <<= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l13
# i3 = 1
# i2 |= i3
# i3 = 2
# i2 <<= (i3 & 31)
# i3 = 5456
# i2 += i3
# i2 = i32_load(Z_envZ_memory, (u64)(i2))
# i1 ^= i2
# i2 = l6
# i3 = 8
# i2 <<= (i3 & 31)
# i3 = l9
# i4 = 24
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l7
# i3 = 16
# i2 <<= (i3 & 31)
# i3 = l5
# i4 = 16
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i2 = l10
# i3 = 24
# i2 <<= (i3 & 31)
# i3 = l0
# i4 = 8
# i3 >>= (i4 & 31)
# i2 |= i3
# i1 ^= i2
# i32_store(Z_envZ_memory, (u64)(i0 + 24), i1)
# i0 = p1
# i1 = l15
# i32_store(Z_envZ_memory, (u64)(i0 + 28), i1)
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 41))
# i1 = 1
# i0 <<= (i1 & 31)
# l0 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# p2 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 50))
# i1 = 1
# i0 <<= (i1 & 31)
# l3 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# i0 = i32_load(Z_envZ_memory, (u64)(i0))
# l8 = i0
# i0 = p0
# i0 = i32_load8_u(Z_envZ_memory, (u64)(i0 + 59))
# i1 = 1
# i0 <<= (i1 & 31)
# l2 = i0
# i1 = 2
# i0 <<= (i1 & 31)
# i1 = 5456
# i0 += i1
# ...
# 0xd7, 0x84, 0x53, 0x31, 0x53, 0xb5, 0x31, 0xd7, 0x84, 0xd5, 0x51, 0xc6,
# 0x51, 0x13, 0xc6, 0x84, 0xd0, 0x03, 0xd3, 0xb8, 0xd3, 0xbb, 0xb8, 0xd0,
# 0x82, 0xdc, 0x5e, 0xc3, 0x5e, 0x1f, 0xc3, 0x82, 0x29, 0xe2, 0xcb, 0xb0,
# 0xcb, 0x52, 0xb0, 0x29, 0x5a, 0xc3, 0x99, 0x77, 0x99, 0xb4, 0x77, 0x5a,
# 0x9c, 0xa4, 0x72, 0xc0, 0xb7, 0xfd, 0x93, 0x26, 0x36, 0x3f, 0xf7, 0xcc,
# 0x34, 0xa5, 0xe5, 0xf1, 0x71, 0xd8, 0x31, 0x15, 0x04, 0xc7, 0x23, 0xc3,
# 0x18, 0x96, 0x05, 0x9a, 0x07, 0x12, 0x80, 0xe2, 0xeb, 0x27, 0xb2, 0x75,
# 0x09, 0x83, 0x2c, 0x1a, 0x1b, 0x6e, 0x5a, 0xa0, 0x52, 0x3b, 0xd6, 0xb3,
# 0x29, 0xe3, 0x2f, 0x84, 0x53, 0xd1, 0x00, 0xed, 0x20, 0xfc, 0xb1, 0x5b,
# 0x6a, 0xcb, 0xbe, 0x39, 0x4a, 0x4c, 0x58, 0xcf, 0xd0, 0xef, 0xaa, 0xfb,
# 0x43, 0x4d, 0x33, 0x85, 0x45, 0xf9, 0x02, 0x7f, 0x50, 0x3c, 0x9f, 0xa8,
# 0x51, 0xa3, 0x40, 0x8f, 0x92, 0x9d, 0x38, 0xf5, 0xbc, 0xb6, 0xda, 0x21,
# 0x10, 0xff, 0xf3, 0xd2, 0xcd, 0x0c, 0x13, 0xec, 0x5f, 0x97, 0x44, 0x17,
# 0xc4, 0xa7, 0x7e, 0x3d, 0x64, 0x5d, 0x19, 0x73, 0x60, 0x81, 0x4f, 0xdc,
# 0x22, 0x2a, 0x90, 0x88, 0x46, 0xee, 0xb8, 0x14, 0xde, 0x5e, 0x0b, 0xdb,
# 0xe0, 0x32, 0x3a, 0x0a, 0x49, 0x06, 0x24, 0x5c, 0xc2, 0xd3, 0xac, 0x62,
# 0x91, 0x95, 0xe4, 0x79, 0xe7, 0xc8, 0x37, 0x6d, 0x8d, 0xd5, 0x4e, 0xa9,
# 0x6c, 0x56, 0xf4, 0xea, 0x65, 0x7a, 0xae, 0x08, 0xba, 0x78, 0x25, 0x2e,
# 0x1c, 0xa6, 0xb4, 0xc6, 0xe8, 0xdd, 0x74, 0x1f, 0x4b, 0xbd, 0x8b, 0x8a,
# 0x70, 0x3e, 0xb5, 0x66, 0x48, 0x03, 0xf6, 0x0e, 0x61, 0x35, 0x57, 0xb9,
# 0x86, 0xc1, 0x1d, 0x9e, 0xe1, 0xf8, 0x98, 0x11, 0x69, 0xd9, 0x8e, 0x94,
# 0x9b, 0x1e, 0x87, 0xe9, 0xce, 0x55, 0x28, 0xdf, 0x8c, 0xa1, 0x89, 0x0d,
# 0xbf, 0xe6, 0x42, 0x68, 0x41, 0x99, 0x2d, 0x0f, 0xb0, 0x54, 0xbb, 0x16,
# 0x01, 0x02, 0x04, 0x08, 0x10, 0x20, 0x40, 0x80, 0x1b, 0x36,
# }
#
# static void init_memory(void) {
# memcpy(&((*Z_envZ_memory).data[1024u]), data_segment_data_0, 5088)
# memcpy(&((*Z_envZ_memory).data[6120u]), data_segment_data_1, 1801)
# memcpy(&((*Z_envZ_memory).data[7984u]), data_segment_data_2, 1738)
# }
#
# static void init_table(void) {
# int32_t offset
# offset = (*Z_envZ_tableBaseZ_i)
# (*Z_envZ_table).data[offset + 0] = (wasm_rt_elem_t){func_types[0], (wasm_rt_anyfunc_t)(&f18)}
# (*Z_envZ_table).data[offset + 1] = (wasm_rt_elem_t){func_types[0], (wasm_rt_anyfunc_t)(&f34)}
# (*Z_envZ_table).data[offset + 2] = (wasm_rt_elem_t){func_types[0], (wasm_rt_anyfunc_t)(&f30)}
# (*Z_envZ_table).data[offset + 3] = (wasm_rt_elem_t){func_types[0], (wasm_rt_anyfunc_t)(&f33)}
# (*Z_envZ_table).data[offset + 4] = (wasm_rt_elem_t){func_types[0], (wasm_rt_anyfunc_t)(&f32_0)}
# (*Z_envZ_table).data[offset + 5] = (wasm_rt_elem_t){func_types[0], (wasm_rt_anyfunc_t)(&f18)}
# (*Z_envZ_table).data[offset + 6] = (wasm_rt_elem_t){func_types[0], (wasm_rt_anyfunc_t)(&f18)}
# (*Z_envZ_table).data[offset + 7] = (wasm_rt_elem_t){func_types[0], (wasm_rt_anyfunc_t)(&f18)}
# }
#
# /* export: '_cryptonight_create' */
# 32 (*WASM_RT_ADD_PREFIX(Z__cryptonight_createZ_iv))(void)
# /* export: '_cryptonight_destroy' */
# void (*WASM_RT_ADD_PREFIX(Z__cryptonight_destroyZ_vi))(u32)
# /* export: '_cryptonight_hash_variant_0' */
# void (*WASM_RT_ADD_PREFIX(Z__cryptonight_hash_variant_0Z_viiii))(u32, u32, u32, u32)
# /* export: '_cryptonight_hash_variant_1' */
# void (*WASM_RT_ADD_PREFIX(Z__cryptonight_hash_variant_1Z_viiii))(u32, u32, u32, u32)
# /* export: '_malloc' */
# 32 (*WASM_RT_ADD_PREFIX(Z__mallocZ_ii))(u32)
# /* export: 'stackAlloc' */
# 32 (*WASM_RT_ADD_PREFIX(Z_stackAllocZ_ii))(u32)
#
# static void init_exports(void) {
# /* export: '_cryptonight_create' */
# WASM_RT_ADD_PREFIX(Z__cryptonight_createZ_iv) = (&_cryptonight_create)
# /* export: '_cryptonight_destroy' */
# WASM_RT_ADD_PREFIX(Z__cryptonight_destroyZ_vi) = (&_cryptonight_destroy)
# /* export: '_cryptonight_hash_variant_0' */
# WASM_RT_ADD_PREFIX(Z__cryptonight_hash_variant_0Z_viiii) = (&_cryptonight_hash_variant_0)
# /* export: '_cryptonight_hash_variant_1' */
# WASM_RT_ADD_PREFIX(Z__cryptonight_hash_variant_1Z_viiii) = (&_cryptonight_hash_variant_1)
# /* export: '_malloc' */
# WASM_RT_ADD_PREFIX(Z__mallocZ_ii) = (&_malloc)
# /* export: 'stackAlloc' */
# WASM_RT_ADD_PREFIX(Z_stackAllocZ_ii) = (&stackAlloc)
# }
#
# void WASM_RT_ADD_PREFIX(init)(void) {
# init_func_types()
# init_globals()
# init_memory()
# init_table()
# init_exports()
# }

# %%
def calormem(temp):
    line = temp.split(' ')
    if line[1] in operater:
        if line[2].split('(')[0] in mem_operater:
            
            return 'mem'
        else:
            #case1 normal situation
            return 'cal'
    else:
        if line[0].split('(')[0] in mem_operater:
            return 'mem'
        else:
            return 'useless'

# %%
for line in lines:
    if calormem(line) == 'mem':
        print(line)
        pass
    if calormem(line) == 'cal':
        #print(line)
        pass
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-9629a339f106> in <module>
#       1 for line in lines:
# ----> 2     if calormem(line) == 'mem':
#       3         print(line)
#       4         pass
#       5     if calormem(line) == 'cal':
#
# <ipython-input-18-597014c73511> in calormem(temp)
#       1 def calormem(temp):
#       2     line = temp.split(' ')
# ----> 3     if line[1] in operater:
#       4         if line[2].split('(')[0] in mem_operater:
#       5
#
# IndexError: list index out of range
